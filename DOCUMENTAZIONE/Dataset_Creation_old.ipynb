# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

from glob import glob

import IPython.display as ipd
from tqdm.notebook import tqdm

import subprocess

import os
from PIL import Image as PImage
from IPython.display import HTML
from base64 import b64encode

import random
from pprint import pprint

# %%
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"         # default location for the drive

drive.mount(ROOT)              # we mount the google drive at /content/drive
# Out:
# Mounted at /content/drive

# %%
directory = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/c23/videos'

# %%
def display_cv2_img(img, figsize=(10, 10)):
  img_=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  fig, ax=plt.subplots(figsize=figsize)
  ax.imshow(img_)
  ax.axis("off")

# %%
cap = cv2.VideoCapture('/content/drive/MyDrive/VISIOPE_PROJECT/dataset/c23/videos/000.mp4')
ret, img = cap.read()
display_cv2_img(img)

from IPython.display import HTML
from base64 import b64encode
 
def show_video(video_path, video_width = 600):
  video_file = open(video_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")
show_video('/content/drive/MyDrive/VISIOPE_PROJECT/dataset/c23/videos/000.mp4')
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>

# %%
 
def show_video(video_path, video_width = 600):
   
  video_file = open(video_path, "r+b").read()
 
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

directory = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/c23/videos'
video_path = directory + '/' + '000.mp4'
show_video(video_path)
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>

# %%
def show_video(video_path, video_width = 600):
   
  video_file = open(video_path, "r+b").read()
 
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

directory = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/Deepfakes/c23/videos'
video_path = directory + '/' + '000_003.mp4'
show_video(video_path)
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>

# %% [markdown]
# ##Save frame of original video in data_original (already done)

# %%
directory = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/c23/videos' 
for filename in os.listdir(directory):
  image_name = filename.replace('.mp4', '')
  file_path = directory + '/' + filename
  #print(file_path)
  cap = cv2.VideoCapture(file_path)
  ret, img = cap.read()
  #show_video(file_path)
  cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_original' + '/' + image_name + '.jpg' , img)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-935f643e6acc> in <module>
#       7   ret, img = cap.read()
#       8   #show_video(file_path)
# ----> 9   cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_original' + '/' + image_name + '.jpg' , img)
#      10
#
# KeyboardInterrupt:

# %% [markdown]
# ##Save frame of Deepfake video in data_deepfake (already done)

# %%
directory_deepfake = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/Deepfakes/c23/videos'
for filename in os.listdir(directory_deepfake):
  image_name = filename.replace('.mp4', '')
  file_path = directory_deepfake + '/' + filename
  cap = cv2.VideoCapture(file_path)
  ret, img = cap.read()
  print(img)
  #show_video(file_path)
  break
  cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_deepfake' + '/' + image_name + '.jpg' , img)

# %% [markdown]
# ##Save frame of Face2Face video in data_face2face (to do)

# %%
directory_face2face = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/Face2Face/c23/videos'
for filename in os.listdir(directory_face2face):
  image_name = filename.replace('.mp4', '')
  file_path = directory_face2face + '/' + filename
  cap = cv2.VideoCapture(file_path)
  ret, img = cap.read()
  #print(img)
  #show_video(file_path)
  cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_face2face' + '/' + image_name + '.jpg' , img)

# %% [markdown]
# ##Save frame of NaturalTextures video in data_naturaltexture (to do)

# %%
directory_naturaltexture = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/NaturalTextures/c23/videos'
for filename in os.listdir(directory_naturaltexture):
  image_name = filename.replace('.mp4', '')
  file_path = directory_naturaltexture + '/' + filename
  cap = cv2.VideoCapture(file_path)
  ret, img = cap.read()
  #print(img)
  #show_video(file_path)
  cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_naturaltexture' + '/' + image_name + '.jpg' , img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-37110300d594> in <module>
#       1 directory_naturaltexture = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/NaturalTextures/c23/videos'
# ----> 2 for filename in os.listdir(directory_naturaltexture):
#       3   image_name = filename.replace('.mp4', '')
#       4   file_path = directory_naturaltexture + '/' + filename
#       5   cap = cv2.VideoCapture(file_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/NaturalTextures/c23/videos'

# %% [markdown]
# ##Save frame of FaceSwap video in data_faceswap (to do)

# %%
directory_faceswap = '/content/drive/MyDrive/VISIOPE_PROJECT/dataset/FaceSwap/c23/videos'
for filename in os.listdir(directory_faceswap):
  image_name = filename.replace('.mp4', '')
  file_path = directory_faceswap + '/' + filename
  cap = cv2.VideoCapture(file_path)
  ret, img = cap.read()
  #print(img)
  #show_video(file_path)
  cv2.imwrite('/content/drive/MyDrive/VISIOPE_PROJECT/data_faceswap' + '/' + image_name + '.jpg' , img)

# %% [markdown]
# ##Associate label:1 to each path original frame

# %%
directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_original'
dataset_list = []
for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': file_path, 'label': 1}
  dataset_list.append(dic)
print(dataset_list)

# %% [markdown]
# ##**Choose one of these:**

# %% [markdown]
# ##Associate label:0 to each path deepfake frame

# %%
directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_deepfake'

for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': file_path, 'label': 0}
  dataset_list.append(dic)
print(dataset_list)

# %% [markdown]
# ##Associate label:0 to each path face2face frame

# %%
directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_face2face'

for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': file_path, 'label': 0}
  dataset_list.append(dic)
print(dataset_list)

# %% [markdown]
# ##Associate label:0 to each path natural texture frame

# %%
directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_naturaltexture'

for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': file_path, 'label': 0}
  dataset_list.append(dic)
print(dataset_list)

# %% [markdown]
# ##Associate label:0 to each path faceswap frame

# %%
directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_faceswap'

for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': file_path, 'label': 0}
  dataset_list.append(dic)
print(dataset_list)

# %% [markdown]
# ##Randomize dataset

# %%
random.shuffle(dataset_list)

# %%
pprint(dataset_list)

# %% [markdown]
# ##Save in a csv file

# %%
#%cd /content/drive/MyDrive/VISIOPE_PROJECT

# %%
"""import csv

keys = dataset_list[0].keys()

with open('DataVisionSet.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(dataset_list)"""

# %% [markdown]
# #CSV with directly images
# ##Associate label to each image

# %%
"""directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_original'
dataset_list = []
for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': img_color, 'label': 1}
  dataset_list.append(dic)
print(dataset_list)"""

# %%
"""directory_dataset = '/content/drive/MyDrive/VISIOPE_PROJECT/data_deepfake'

for filename in os.listdir(directory_dataset):
  #print(filename)
  file_path = directory_dataset + '/' + filename
  img_color = cv2.imread(file_path,1)
  #display_cv2_img(img_color)
  dic = {'image': img_color, 'label': 0}
  dataset_list.append(dic)
print(dataset_list)"""

# %% [markdown]
# ###Randomize dataset

# %%
"""random.shuffle(dataset_list)
pprint(dataset_list)"""

# %% [markdown]
# #Save into a CSV file

# %%
"""%cd /content/drive/MyDrive/VISIOPE_PROJECT"""

# %%
"""import csv

keys = dataset_list[0].keys()

with open('DataVisionSetImages.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(dataset_list)"""

# %% [markdown]
# # Divide in Train and Val dataset

# %%
count = 0
data_original = '/content/drive/MyDrive/VISIOPE_PROJECT/data_original'
for filename in os.listdir(data_original):
  file_path = data_original + '/' + filename
  img = cv2.imread(file_path)
  if count < 699:

    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_deepfake/train/real/') 
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_face2face/train/real/')
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_faceswap/train/real/')
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_naturaltexture/train/real/')

    cv2.imwrite(filename, img)
  if count >= 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_deepfake/val/real/')
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_face2face/val/real/')
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_faceswap/val/real/')
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_naturaltexture/val/real/')

    cv2.imwrite(filename, img)
  count += 1

# %% [markdown]
# ## DEEPFAKE:

# %%
count = 0
deep_fake = '/content/drive/MyDrive/VISIOPE_PROJECT/data_deepfake'
for filename in os.listdir(deep_fake):
  file_path = deep_fake + '/' + filename
  img = cv2.imread(file_path)
  if count < 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_deepfake/train/fake/') 
    cv2.imwrite(filename, img)
  if count >= 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_deepfake/val/fake/')
    cv2.imwrite(filename, img)
  count += 1

# %% [markdown]
# ## FACE2FACE

# %%
count = 0
deep_fake = '/content/drive/MyDrive/VISIOPE_PROJECT/data_face2face'
for filename in os.listdir(deep_fake):
  file_path = deep_fake + '/' + filename
  img = cv2.imread(file_path)
  if count < 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_face2face/train/fake/') 
    cv2.imwrite(filename, img)
  if count >= 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_face2face/val/fake/')
    cv2.imwrite(filename, img)
  count += 1

# %% [markdown]
# ## FACESWAP

# %%
count = 0
deep_fake = '/content/drive/MyDrive/VISIOPE_PROJECT/data_faceswap'
for filename in os.listdir(deep_fake):
  file_path = deep_fake + '/' + filename
  img = cv2.imread(file_path)
  if count < 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_faceswap/train/fake/') 
    cv2.imwrite(filename, img)
  if count >= 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_faceswap/val/fake/')
    cv2.imwrite(filename, img)
  count += 1

# %% [markdown]
# ## NATURAL TEXTURE

# %%
count = 0
deep_fake = '/content/drive/MyDrive/VISIOPE_PROJECT/data_naturaltexture'
for filename in os.listdir(deep_fake):
  file_path = deep_fake + '/' + filename
  img = cv2.imread(file_path)
  if count < 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_naturaltexture/train/fake/') 
    cv2.imwrite(filename, img)
  if count >= 699:
    os.chdir('/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_naturaltexture/val/fake/')
    cv2.imwrite(filename, img)
  count += 1
