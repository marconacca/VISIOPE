# %% [markdown]
# # Transfer Learning DeepFake
# We present a fake detection task on DeepFake manipulation, performed with the use of a pre-trained **Resnet50 model**. We try to evaluate the performance of the network using transfer learning in two different way:
#
# *   Take the weights of the pretrained model as intial weigths and fine-tuning the pre-trained *Xception model* on the *DeepFake dataset*
# *   Freezing the weights of all the layer of the pretrained model and going to add, as last layer, one linear layers with a ReLu activation function, which is the only one retrained on the *DeepFake dataset*.

# %% [markdown]
# ## IMPORT

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision.models import resnet50, ResNet50_Weights
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image
import random
import matplotlib.image as mpimg
import pandas as pd
from google.colab import drive
import cv2

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# ##Load Data

# %% [markdown]
# ###Folder

# %%
drive.mount('/content/drive/')
data_dir = '/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSet_deepfake/'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ##DataLoader with augmentation and normalization
#
# In the following block, we create the ImageFolder (one for the train and one for the validation set), and the dataloaders, necessary for the training phase.
# In particular we create batches of 4 images.

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ##Visualize a few images

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Visualizing the model predictions
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            print(f'Labels:{labels}')

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            print(f'Prediction:{preds}')
            print(f'Input size: {inputs.size()[0]}')
            print(f'Class names: {class_names}')

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## FINETUNING THE RESNET
#
#
#
# > REsNet-50 is a deep residual neural network architecture developed by Microsoft. It's a variant of the ResNet architecure, which is designed to improve the trade-off between accuracy and computational cost by addressing the problem of vanishing gradients in deep neural networks.

# %% [markdown]
# # RESNET50

# %% [markdown]
# > In this situation, we create a pre-trained *ResNet model*, trained on Imagenet, named `model_ft`, and we retrain it on the DeepFake dataset.
#
# > There, we use an *SGD optimizer*, with a initial learning rate really low ( `lr=0.001`) with a *StepLR scheduler*.

# %%
model_ft = resnet50(weights=ResNet50_Weights.DEFAULT)
num_ftrs = model_ft.fc.in_features

# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
# optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
model_ft

# %% [markdown]
# ## FINETUNING THE RESNET FREEZING INITIAL LAYERS
#
#
#
# > In this situation instead, we create a ResNet pre-trained model, `model_ft_freeze`, we freeze all the weigths of the network and finally we add a `nn.Sequential` composed of one linear layers with a Relu in between.
#
# For this case, we use an *SGD optimezer* with an *StepLR scheduler* which decrease the learning rate every 7 epochs.

# %%
model_ft_freeze = resnet50(weights=ResNet50_Weights.DEFAULT)

for param in model_ft_freeze.parameters():
    param.requiresGrad = False

num_ftrs = model_ft_freeze.fc.in_features

model_ft_freeze.fc = nn.Linear(num_ftrs, 2)

model_ft_freeze = model_ft_freeze.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft_freeze.parameters(), lr=0.001, momentum=0.9)
# optimizer_ft = optim.Adam(model_ft_freeze.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft_freeze

# %% [markdown]
# ## Define train_model function

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    train_loss=[]
    val_loss=[]

    train_acc=[]
    val_acc=[]

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase=='train':
              train_loss.append(epoch_loss)
              train_acc.append(epoch_acc.item())
            else:
              val_loss.append(epoch_loss)
              val_acc.append(epoch_acc.item())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return {'model': model, 'train_loss':train_loss, 'val_loss':val_loss, 'train_acc': train_acc, 'val_acc': val_acc}

# %% [markdown]
# ## Train and evaluate

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# train Loss: 0.5669 Acc: 0.6863
# val Loss: 0.3779 Acc: 0.8250
#
# Epoch 1/49
# ----------
# train Loss: 0.3916 Acc: 0.8200
# val Loss: 0.3701 Acc: 0.8350
#
# Epoch 2/49
# ----------
# train Loss: 0.3215 Acc: 0.8625
# val Loss: 0.2674 Acc: 0.9100
#
# Epoch 3/49
# ----------
# train Loss: 0.2345 Acc: 0.9050
# val Loss: 0.2041 Acc: 0.9250
#
# Epoch 4/49
# ----------
# train Loss: 0.2044 Acc: 0.9088
# val Loss: 0.1567 Acc: 0.9250
#
# Epoch 5/49
# ----------
# train Loss: 0.1551 Acc: 0.9363
# val Loss: 0.2392 Acc: 0.8900
#
# Epoch 6/49
# ----------
# train Loss: 0.1193 Acc: 0.9544
# val Loss: 0.2269 Acc: 0.9150
#
# Epoch 7/49
# ----------
# train Loss: 0.0652 Acc: 0.9781
# val Loss: 0.1737 Acc: 0.9400
#
# Epoch 8/49
# ----------
# train Loss: 0.0498 Acc: 0.9850
# val Loss: 0.1562 Acc: 0.9450
#
# Epoch 9/49
# ----------
# train Loss: 0.0448 Acc: 0.9875
# val Loss: 0.1618 Acc: 0.9550
#
# Epoch 10/49
# ----------
# train Loss: 0.0457 Acc: 0.9819
# val Loss: 0.1583 Acc: 0.9550
#
# Epoch 11/49
# ----------
# train Loss: 0.0416 Acc: 0.9888
# val Loss: 0.1486 Acc: 0.9500
#
# Epoch 12/49
# ----------
# train Loss: 0.0305 Acc: 0.9925
# val Loss: 0.1414 Acc: 0.9500
#
# Epoch 13/49
# ----------
# train Loss: 0.0328 Acc: 0.9888
# val Loss: 0.1440 Acc: 0.9500
#
# Epoch 14/49
# ----------
# train Loss: 0.0353 Acc: 0.9863
# val Loss: 0.1402 Acc: 0.9450
#
# Epoch 15/49
# ----------
# train Loss: 0.0288 Acc: 0.9906
# val Loss: 0.1506 Acc: 0.9450
#
# Epoch 16/49
# ----------
# train Loss: 0.0270 Acc: 0.9919
# val Loss: 0.1520 Acc: 0.9450
#
# Epoch 17/49
# ----------
# train Loss: 0.0289 Acc: 0.9900
# val Loss: 0.1405 Acc: 0.9500
#
# Epoch 18/49
# ----------
# train Loss: 0.0321 Acc: 0.9900
# val Loss: 0.1362 Acc: 0.9450
#
# Epoch 19/49
# ----------
# train Loss: 0.0278 Acc: 0.9894
# val Loss: 0.1453 Acc: 0.9500
#
# Epoch 20/49
# ----------
# train Loss: 0.0264 Acc: 0.9925
# val Loss: 0.1487 Acc: 0.9500
#
# Epoch 21/49
# ----------
# train Loss: 0.0242 Acc: 0.9938
# val Loss: 0.1546 Acc: 0.9400
#
# Epoch 22/49
# ----------
# train Loss: 0.0257 Acc: 0.9931
# val Loss: 0.1483 Acc: 0.9600
#
# Epoch 23/49
# ----------
# train Loss: 0.0244 Acc: 0.9925
# val Loss: 0.1427 Acc: 0.9450
#
# Epoch 24/49
# ----------
# train Loss: 0.0277 Acc: 0.9931
# val Loss: 0.1530 Acc: 0.9250
#
# Epoch 25/49
# ----------
# train Loss: 0.0245 Acc: 0.9950
# val Loss: 0.1529 Acc: 0.9450
#
# Epoch 26/49
# ----------
# train Loss: 0.0265 Acc: 0.9938
# val Loss: 0.1546 Acc: 0.9350
#
# Epoch 27/49
# ----------
# train Loss: 0.0265 Acc: 0.9931
# val Loss: 0.1395 Acc: 0.9550
#
# Epoch 28/49
# ----------
# train Loss: 0.0239 Acc: 0.9962
# val Loss: 0.1527 Acc: 0.9400
#
# Epoch 29/49
# ----------
# train Loss: 0.0257 Acc: 0.9925
# val Loss: 0.1476 Acc: 0.9350
#
# Epoch 30/49
# ----------
# train Loss: 0.0274 Acc: 0.9931
# val Loss: 0.1429 Acc: 0.9550
#
# Epoch 31/49
# ----------
# train Loss: 0.0273 Acc: 0.9925
# val Loss: 0.1402 Acc: 0.9400
#
# Epoch 32/49
# ----------
# train Loss: 0.0245 Acc: 0.9931
# val Loss: 0.1500 Acc: 0.9250
#
# Epoch 33/49
# ----------
# train Loss: 0.0262 Acc: 0.9931
# val Loss: 0.1535 Acc: 0.9450
#
# Epoch 34/49
# ----------
# train Loss: 0.0316 Acc: 0.9894
# val Loss: 0.1453 Acc: 0.9450
#
# Epoch 35/49
# ----------
# train Loss: 0.0290 Acc: 0.9919
# val Loss: 0.1569 Acc: 0.9450
#
# Epoch 36/49
# ----------
# train Loss: 0.0280 Acc: 0.9906
# val Loss: 0.1549 Acc: 0.9450
#
# Epoch 37/49
# ----------
# train Loss: 0.0316 Acc: 0.9913
# val Loss: 0.1502 Acc: 0.9300
#
# Epoch 38/49
# ----------
# train Loss: 0.0293 Acc: 0.9913
# val Loss: 0.1401 Acc: 0.9450
#
# Epoch 39/49
# ----------
# train Loss: 0.0261 Acc: 0.9944
# val Loss: 0.1570 Acc: 0.9500
#
# Epoch 40/49
# ----------
# train Loss: 0.0272 Acc: 0.9925
# val Loss: 0.1457 Acc: 0.9450
#
# Epoch 41/49
# ----------
# train Loss: 0.0226 Acc: 0.9962
# val Loss: 0.1539 Acc: 0.9450
#
# Epoch 42/49
# ----------
# train Loss: 0.0274 Acc: 0.9913
# val Loss: 0.1456 Acc: 0.9400
#
# Epoch 43/49
# ----------
# train Loss: 0.0261 Acc: 0.9944
# val Loss: 0.1396 Acc: 0.9500
#
# Epoch 44/49
# ----------
# train Loss: 0.0342 Acc: 0.9894
# val Loss: 0.1628 Acc: 0.9450
#
# Epoch 45/49
# ----------
# train Loss: 0.0256 Acc: 0.9956
# val Loss: 0.1434 Acc: 0.9350
#
# Epoch 46/49
# ----------
# train Loss: 0.0266 Acc: 0.9925
# val Loss: 0.1502 Acc: 0.9450
#
# Epoch 47/49
# ----------
# train Loss: 0.0290 Acc: 0.9944
# val Loss: 0.1466 Acc: 0.9450
#
# Epoch 48/49
# ----------
# train Loss: 0.0280 Acc: 0.9919
# val Loss: 0.1556 Acc: 0.9500
#
# Epoch 49/49
# ----------
# train Loss: 0.0265 Acc: 0.9925
# val Loss: 0.1411 Acc: 0.9450
#
# Training complete in 22m 24s
# Best val Acc: 0.960000

# %%
model_ft_freeze = train_model(model_ft_freeze, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# train Loss: 0.5977 Acc: 0.6744
# val Loss: 0.3528 Acc: 0.9100
#
# Epoch 1/49
# ----------
# train Loss: 0.4351 Acc: 0.7931
# val Loss: 0.2825 Acc: 0.8850
#
# Epoch 2/49
# ----------
# train Loss: 0.3509 Acc: 0.8456
# val Loss: 0.2134 Acc: 0.9200
#
# Epoch 3/49
# ----------
# train Loss: 0.2567 Acc: 0.8844
# val Loss: 0.2139 Acc: 0.9350
#
# Epoch 4/49
# ----------
# train Loss: 0.2116 Acc: 0.9081
# val Loss: 0.1906 Acc: 0.9300
#
# Epoch 5/49
# ----------
# train Loss: 0.1680 Acc: 0.9300
# val Loss: 0.2288 Acc: 0.9150
#
# Epoch 6/49
# ----------
# train Loss: 0.1269 Acc: 0.9513
# val Loss: 0.1793 Acc: 0.9250
#
# Epoch 7/49
# ----------
# train Loss: 0.1016 Acc: 0.9594
# val Loss: 0.1583 Acc: 0.9400
#
# Epoch 8/49
# ----------
# train Loss: 0.0708 Acc: 0.9713
# val Loss: 0.1692 Acc: 0.9350
#
# Epoch 9/49
# ----------
# train Loss: 0.0593 Acc: 0.9813
# val Loss: 0.1839 Acc: 0.9350
#
# Epoch 10/49
# ----------
# train Loss: 0.0637 Acc: 0.9719
# val Loss: 0.1489 Acc: 0.9450
#
# Epoch 11/49
# ----------
# train Loss: 0.0515 Acc: 0.9825
# val Loss: 0.1529 Acc: 0.9400
#
# Epoch 12/49
# ----------
# train Loss: 0.0538 Acc: 0.9800
# val Loss: 0.1334 Acc: 0.9500
#
# Epoch 13/49
# ----------
# train Loss: 0.0479 Acc: 0.9838
# val Loss: 0.1485 Acc: 0.9550
#
# Epoch 14/49
# ----------
# train Loss: 0.0434 Acc: 0.9838
# val Loss: 0.1431 Acc: 0.9550
#
# Epoch 15/49
# ----------
# train Loss: 0.0369 Acc: 0.9894
# val Loss: 0.1544 Acc: 0.9500
#
# Epoch 16/49
# ----------
# train Loss: 0.0401 Acc: 0.9900
# val Loss: 0.1508 Acc: 0.9400
#
# Epoch 17/49
# ----------
# train Loss: 0.0460 Acc: 0.9813
# val Loss: 0.1418 Acc: 0.9400
#
# Epoch 18/49
# ----------
# train Loss: 0.0360 Acc: 0.9906
# val Loss: 0.1498 Acc: 0.9550
#
# Epoch 19/49
# ----------
# train Loss: 0.0362 Acc: 0.9888
# val Loss: 0.1584 Acc: 0.9400
#
# Epoch 20/49
# ----------
# train Loss: 0.0412 Acc: 0.9863
# val Loss: 0.1592 Acc: 0.9450
#
# Epoch 21/49
# ----------
# train Loss: 0.0438 Acc: 0.9831
# val Loss: 0.1477 Acc: 0.9400
#
# Epoch 22/49
# ----------
# train Loss: 0.0410 Acc: 0.9863
# val Loss: 0.1549 Acc: 0.9450
#
# Epoch 23/49
# ----------
# train Loss: 0.0366 Acc: 0.9900
# val Loss: 0.1665 Acc: 0.9400
#
# Epoch 24/49
# ----------
# train Loss: 0.0384 Acc: 0.9894
# val Loss: 0.1734 Acc: 0.9350
#
# Epoch 25/49
# ----------
# train Loss: 0.0392 Acc: 0.9875
# val Loss: 0.1482 Acc: 0.9500
#
# Epoch 26/49
# ----------
# train Loss: 0.0379 Acc: 0.9863
# val Loss: 0.1444 Acc: 0.9450
#
# Epoch 27/49
# ----------
# train Loss: 0.0407 Acc: 0.9881
# val Loss: 0.1774 Acc: 0.9500
#
# Epoch 28/49
# ----------
# train Loss: 0.0350 Acc: 0.9900
# val Loss: 0.1501 Acc: 0.9550
#
# Epoch 29/49
# ----------
# train Loss: 0.0342 Acc: 0.9913
# val Loss: 0.1489 Acc: 0.9500
#
# Epoch 30/49
# ----------
# train Loss: 0.0366 Acc: 0.9900
# val Loss: 0.1545 Acc: 0.9550
#
# Epoch 31/49
# ----------
# train Loss: 0.0386 Acc: 0.9900
# val Loss: 0.1832 Acc: 0.9350
#
# Epoch 32/49
# ----------
# train Loss: 0.0388 Acc: 0.9894
# val Loss: 0.1337 Acc: 0.9450
#
# Epoch 33/49
# ----------
# train Loss: 0.0385 Acc: 0.9869
# val Loss: 0.1393 Acc: 0.9400
#
# Epoch 34/49
# ----------
# train Loss: 0.0421 Acc: 0.9844
# val Loss: 0.1786 Acc: 0.9450
#
# Epoch 35/49
# ----------
# train Loss: 0.0368 Acc: 0.9875
# val Loss: 0.1261 Acc: 0.9550
#
# Epoch 36/49
# ----------
# train Loss: 0.0387 Acc: 0.9869
# val Loss: 0.1619 Acc: 0.9400
#
# Epoch 37/49
# ----------
# train Loss: 0.0357 Acc: 0.9894
# val Loss: 0.1488 Acc: 0.9550
#
# Epoch 38/49
# ----------
# train Loss: 0.0391 Acc: 0.9900
# val Loss: 0.1362 Acc: 0.9500
#
# Epoch 39/49
# ----------
# train Loss: 0.0334 Acc: 0.9900
# val Loss: 0.1335 Acc: 0.9400
#
# Epoch 40/49
# ----------
# train Loss: 0.0333 Acc: 0.9881
# val Loss: 0.1530 Acc: 0.9500
#
# Epoch 41/49
# ----------
# train Loss: 0.0381 Acc: 0.9875
# val Loss: 0.1642 Acc: 0.9500
#
# Epoch 42/49
# ----------
# train Loss: 0.0420 Acc: 0.9819
# val Loss: 0.1381 Acc: 0.9450
#
# Epoch 43/49
# ----------
# train Loss: 0.0376 Acc: 0.9863
# val Loss: 0.1707 Acc: 0.9450
#
# Epoch 44/49
# ----------
# train Loss: 0.0405 Acc: 0.9856
# val Loss: 0.1452 Acc: 0.9550
#
# Epoch 45/49
# ----------
# train Loss: 0.0366 Acc: 0.9881
# val Loss: 0.1390 Acc: 0.9600
#
# Epoch 46/49
# ----------
# train Loss: 0.0395 Acc: 0.9869
# val Loss: 0.1362 Acc: 0.9400
#
# Epoch 47/49
# ----------
# train Loss: 0.0388 Acc: 0.9900
# val Loss: 0.1557 Acc: 0.9500
#
# Epoch 48/49
# ----------
# train Loss: 0.0383 Acc: 0.9881
# val Loss: 0.1566 Acc: 0.9400
#
# Epoch 49/49
# ----------
# train Loss: 0.0398 Acc: 0.9869
# val Loss: 0.1403 Acc: 0.9450
#
# Training complete in 23m 29s
# Best val Acc: 0.960000

# %% [markdown]
# # Visualize few image of the model without freezing layers

# %%
visualize_model(model_ft['model'])

plt.ioff()
plt.show()

# %% [markdown]
# # Visualize few image of the model with freezing layers

# %%
visualize_model(model_ft_freeze['model'])

plt.ioff()
plt.show()

# %% [markdown]
# # Plot Train Loss and Accuracy
#
#
#
# > In this section we plot the `training` and `validation loss` and the `accuracy` of our model without freezing layers.

# %%
def plot_logs(train_loss, valid_loss, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_loss))), train_loss, label='Train loss')
    plt.plot(list(range(len(valid_loss))), valid_loss, label='Valid loss')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc="upper right")

    plt.show()

plot_logs(model_ft['train_loss'], model_ft['val_loss'], 'Train vs Valid loss')

# %%
def plot_acc(train_acc, valid_acc, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_acc))), train_acc, label='Train accuracy')
    plt.plot(list(range(len(valid_acc))), valid_acc, label='Valid accuracy')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc="upper right")

    plt.show()
# oppure model_ft_freeze
plot_acc(model_ft['train_acc'], model_ft['val_acc'], 'Train vs Valid Accuracy')

# %% [markdown]
# # Plot Train Loss and Accuracy
#
#
#
# > In this section we plot the `training` and `validation loss` and the `accuracy` of our model with freezing layers.

# %%
def plot_logs(train_loss, valid_loss, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_loss))), train_loss, label='Train loss')
    plt.plot(list(range(len(valid_loss))), valid_loss, label='Valid loss')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc="upper right")

    plt.show()

plot_logs(model_ft_freeze['train_loss'], model_ft_freeze['val_loss'], 'Train vs Valid loss')

# %%
def plot_acc(train_acc, valid_acc, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_acc))), train_acc, label='Train accuracy')
    plt.plot(list(range(len(valid_acc))), valid_acc, label='Valid accuracy')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc="upper right")

    plt.show()
# oppure model_ft_freeze
plot_acc(model_ft_freeze['train_acc'], model_ft_freeze['val_acc'], 'Train vs Valid Accuracy')

# %% [markdown]
# ## SAVE THE MODEL

# %%
# %cd /content/drive/MyDrive/VISIOPE_PROJECT/models
# Out:
# /content/drive/MyDrive/VISIOPE_PROJECT/models

# %% [markdown]
# ## WITHOUT FREEZING

# %%
torch.save(model_ft['model'].state_dict(), 'resnet50_deepfake_NORMAL_ADAM_pt2.pt')

# %% [markdown]
# ## FREEZING

# %%
torch.save(model_ft_freeze['model'].state_dict(), 'resnet50_deepfake_FREEZE.pt')
