# %% [markdown]
# # Transfer Learning Mix
# We present a fake detection task on FaceForensic manipulations, performed with the use of a pre-trained **Resnet50 model**. We try to evaluate the performance of the network using transfer learning in two different way:
#
# *   Take the weights of the pretrained model as intial weigths and fine-tuning the pre-trained *ResNet model* on the *entire FaceForensic dataset*
# *   Freezing the weights of all the layer of the pretrained model and going to add, as last layer, one linear layers with a ReLu activation function, which is the only one retrained on the *FaceForensic dataset*.

# %% [markdown]
# ## IMPORT

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision.models import resnet50, ResNet50_Weights
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image
import random
import matplotlib.image as mpimg
import pandas as pd
from google.colab import drive
import cv2

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# ##Load Data

# %% [markdown]
# ###Folder

# %%
drive.mount('/content/drive/')
data_dir = '/content/drive/MyDrive/VISIOPE_PROJECT/DataVisionSetMix/'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ##DataLoader with augmentation and normalization
#
#
#
# > In the following block, we create the ImageFolder (one for the train and one for the validation set), and the dataloaders, necessary for the training phase.
# In particular we create batches of 4 images.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ##Visualize a few images

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Visualizing the model predictions
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            print(f'Labels:{labels}')

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            print(f'Prediction:{preds}')
            print(f'Input size: {inputs.size()[0]}')
            print(f'Class names: {class_names}')

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## FINETUNING THE RESNET
#
#
#
# > REsNet-50 is a deep residual neural network architecture developed by Microsoft. It's a variant of the ResNet architecure, which is designed to improve the trade-off between accuracy and computational cost by addressing the problem of vanishing gradients in deep neural networks.

# %% [markdown]
# # RESNET50

# %% [markdown]
# > In this situation, we create a pre-trained *ResNet model*, trained on Imagenet, named `model_ft`, and we retrain it on the FaceForensic dataset.
#
# > There, we use an *SGD optimizer*, with a initial learning rate really low ( `lr=0.001`) with a *StepLR scheduler*.

# %%
model_ft = resnet50(weights=ResNet50_Weights.DEFAULT)
num_ftrs = model_ft.fc.in_features

model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft

# %% [markdown]
# ## FINETUNING THE RESNET FREEZING INITIAL LAYERS
#
#
#
# > In this situation instead, we create a ResNet pre-trained model, `model_ft_freeze`, we freeze all the weigths of the network and finally we add a `nn.Sequential` composed of one linear layers with a Relu in between.
#
# For this case, we use an *SGD optimezer* with an *StepLR scheduler* which decrease the learning rate every 7 epochs.

# %%
model_ft_freeze = resnet50(weights=ResNet50_Weights.DEFAULT)

for param in model_ft_freeze.parameters():
    param.requiresGrad = False

num_ftrs = model_ft_freeze.fc.in_features

model_ft_freeze.fc = nn.Linear(num_ftrs, 2)

model_ft_freeze = model_ft_freeze.to(device)

criterion = nn.CrossEntropyLoss()

# optimizer_ft = optim.SGD(model_ft_freeze.parameters(), lr=0.001, momentum=0.9)
optimizer_ft = optim.Adam(model_ft_freeze.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft_freeze

# %% [markdown]
# ## Define train_model function

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    train_loss=[]
    val_loss=[]

    train_acc=[]
    val_acc=[]

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase=='train':
              train_loss.append(epoch_loss)
              train_acc.append(epoch_acc.item())
            else:
              val_loss.append(epoch_loss)
              val_acc.append(epoch_acc.item())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return {'model': model, 'train_loss':train_loss, 'val_loss':val_loss, 'train_acc': train_acc, 'val_acc': val_acc}

# %% [markdown]
# ## Train and evaluate

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.7005 Acc: 0.5187
# val Loss: 0.7385 Acc: 0.4513
#
# Epoch 1/99
# ----------
# train Loss: 0.6661 Acc: 0.6103
# val Loss: 0.6192 Acc: 0.6721
#
# Epoch 2/99
# ----------
# train Loss: 0.6239 Acc: 0.6496
# val Loss: 0.6879 Acc: 0.6234
#
# Epoch 3/99
# ----------
# train Loss: 0.5741 Acc: 0.7007
# val Loss: 0.5309 Acc: 0.7370
#
# Epoch 4/99
# ----------
# train Loss: 0.5122 Acc: 0.7425
# val Loss: 0.5067 Acc: 0.7500
#
# Epoch 5/99
# ----------
# train Loss: 0.4620 Acc: 0.7887
# val Loss: 0.6238 Acc: 0.6916
#
# Epoch 6/99
# ----------
# train Loss: 0.4082 Acc: 0.8111
# val Loss: 0.4505 Acc: 0.8052
#
# Epoch 7/99
# ----------
# train Loss: 0.2931 Acc: 0.8859
# val Loss: 0.4587 Acc: 0.7890
#
# Epoch 8/99
# ----------
# train Loss: 0.2379 Acc: 0.9102
# val Loss: 0.4819 Acc: 0.7760
#
# Epoch 9/99
# ----------
# train Loss: 0.2001 Acc: 0.9233
# val Loss: 0.4842 Acc: 0.7662
#
# Epoch 10/99
# ----------
# train Loss: 0.1945 Acc: 0.9208
# val Loss: 0.4425 Acc: 0.7987
#
# Epoch 11/99
# ----------
# train Loss: 0.1624 Acc: 0.9377
# val Loss: 0.4022 Acc: 0.8247
#
# Epoch 12/99
# ----------
# train Loss: 0.1552 Acc: 0.9414
# val Loss: 0.5393 Acc: 0.7597
#
# Epoch 13/99
# ----------
# train Loss: 0.1358 Acc: 0.9495
# val Loss: 0.5582 Acc: 0.7597
#
# Epoch 14/99
# ----------
# train Loss: 0.1338 Acc: 0.9526
# val Loss: 0.6172 Acc: 0.7403
#
# Epoch 15/99
# ----------
# train Loss: 0.1187 Acc: 0.9613
# val Loss: 0.4960 Acc: 0.7825
#
# Epoch 16/99
# ----------
# train Loss: 0.1205 Acc: 0.9582
# val Loss: 0.5417 Acc: 0.7695
#
# Epoch 17/99
# ----------
# train Loss: 0.1242 Acc: 0.9514
# val Loss: 0.4655 Acc: 0.8149
#
# Epoch 18/99
# ----------
# train Loss: 0.1197 Acc: 0.9532
# val Loss: 0.5715 Acc: 0.7630
#
# Epoch 19/99
# ----------
# train Loss: 0.1276 Acc: 0.9507
# val Loss: 0.5385 Acc: 0.7792
#
# Epoch 20/99
# ----------
# train Loss: 0.1139 Acc: 0.9564
# val Loss: 0.5697 Acc: 0.7727
#
# Epoch 21/99
# ----------
# train Loss: 0.1146 Acc: 0.9620
# val Loss: 0.5254 Acc: 0.7792
#
# Epoch 22/99
# ----------
# train Loss: 0.1196 Acc: 0.9564
# val Loss: 0.4465 Acc: 0.8084
#
# Epoch 23/99
# ----------
# train Loss: 0.1100 Acc: 0.9613
# val Loss: 0.5201 Acc: 0.7922
#
# Epoch 24/99
# ----------
# train Loss: 0.1232 Acc: 0.9545
# val Loss: 0.5854 Acc: 0.7662
#
# Epoch 25/99
# ----------
# train Loss: 0.1118 Acc: 0.9601
# val Loss: 0.5070 Acc: 0.7792
#
# Epoch 26/99
# ----------
# train Loss: 0.1087 Acc: 0.9607
# val Loss: 0.7397 Acc: 0.7078
#
# Epoch 27/99
# ----------
# train Loss: 0.1109 Acc: 0.9582
# val Loss: 0.5500 Acc: 0.7857
#
# Epoch 28/99
# ----------
# train Loss: 0.1080 Acc: 0.9670
# val Loss: 0.5615 Acc: 0.7727
#
# Epoch 29/99
# ----------
# train Loss: 0.1263 Acc: 0.9520
# val Loss: 0.4777 Acc: 0.7987
#
# Epoch 30/99
# ----------
# train Loss: 0.1185 Acc: 0.9589
# val Loss: 0.4941 Acc: 0.7955
#
# Epoch 31/99
# ----------
# train Loss: 0.1053 Acc: 0.9632
# val Loss: 0.5783 Acc: 0.7597
#
# Epoch 32/99
# ----------
# train Loss: 0.1086 Acc: 0.9551
# val Loss: 0.5421 Acc: 0.7695
#
# Epoch 33/99
# ----------
# train Loss: 0.1175 Acc: 0.9601
# val Loss: 0.5622 Acc: 0.7597
#
# Epoch 34/99
# ----------
# train Loss: 0.1087 Acc: 0.9613
# val Loss: 0.5873 Acc: 0.7792
#
# Epoch 35/99
# ----------
# train Loss: 0.1219 Acc: 0.9582
# val Loss: 0.4941 Acc: 0.7825
#
# Epoch 36/99
# ----------
# train Loss: 0.1122 Acc: 0.9632
# val Loss: 0.5354 Acc: 0.7727
#
# Epoch 37/99
# ----------
# train Loss: 0.1084 Acc: 0.9638
# val Loss: 0.4986 Acc: 0.7890
#
# Epoch 38/99
# ----------
# train Loss: 0.1183 Acc: 0.9539
# val Loss: 0.4914 Acc: 0.7662
#
# Epoch 39/99
# ----------
# train Loss: 0.1108 Acc: 0.9638
# val Loss: 0.4892 Acc: 0.7955
#
# Epoch 40/99
# ----------
# train Loss: 0.1125 Acc: 0.9601
# val Loss: 0.5075 Acc: 0.7825
#
# Epoch 41/99
# ----------
# train Loss: 0.1169 Acc: 0.9564
# val Loss: 0.5023 Acc: 0.7857
#
# Epoch 42/99
# ----------
# train Loss: 0.1141 Acc: 0.9564
# val Loss: 0.5487 Acc: 0.7825
#
# Epoch 43/99
# ----------
# train Loss: 0.1089 Acc: 0.9645
# val Loss: 0.5205 Acc: 0.7792
#
# Epoch 44/99
# ----------
# train Loss: 0.1150 Acc: 0.9564
# val Loss: 0.4926 Acc: 0.7792
#
# Epoch 45/99
# ----------
# train Loss: 0.1079 Acc: 0.9620
# val Loss: 0.5506 Acc: 0.7922
#
# Epoch 46/99
# ----------
# train Loss: 0.1243 Acc: 0.9520
# val Loss: 0.5350 Acc: 0.7922
#
# Epoch 47/99
# ----------
# train Loss: 0.1151 Acc: 0.9626
# val Loss: 0.5063 Acc: 0.7890
#
# Epoch 48/99
# ----------
# train Loss: 0.1174 Acc: 0.9632
# val Loss: 0.4486 Acc: 0.8117
#
# Epoch 49/99
# ----------
# train Loss: 0.1009 Acc: 0.9645
# val Loss: 0.4671 Acc: 0.7987
#
# Epoch 50/99
# ----------
# train Loss: 0.1190 Acc: 0.9526
# val Loss: 0.5598 Acc: 0.7695
#
# Epoch 51/99
# ----------
# train Loss: 0.1288 Acc: 0.9470
# val Loss: 0.4994 Acc: 0.7955
#
# Epoch 52/99
# ----------
# train Loss: 0.1101 Acc: 0.9576
# val Loss: 0.5724 Acc: 0.7403
#
# Epoch 53/99
# ----------
# train Loss: 0.1116 Acc: 0.9576
# val Loss: 0.4801 Acc: 0.7825
#
# Epoch 54/99
# ----------
# train Loss: 0.1294 Acc: 0.9551
# val Loss: 0.5215 Acc: 0.7890
#
# Epoch 55/99
# ----------
# train Loss: 0.1152 Acc: 0.9626
# val Loss: 0.4661 Acc: 0.8182
#
# Epoch 56/99
# ----------
# train Loss: 0.1205 Acc: 0.9545
# val Loss: 0.4968 Acc: 0.7727
#
# Epoch 57/99
# ----------
# train Loss: 0.1150 Acc: 0.9595
# val Loss: 0.4678 Acc: 0.7955
#
# Epoch 58/99
# ----------
# train Loss: 0.1204 Acc: 0.9601
# val Loss: 0.4209 Acc: 0.8344
#
# Epoch 59/99
# ----------
# train Loss: 0.1270 Acc: 0.9539
# val Loss: 0.5095 Acc: 0.7825
#
# Epoch 60/99
# ----------
# train Loss: 0.1096 Acc: 0.9663
# val Loss: 0.5688 Acc: 0.7727
#
# Epoch 61/99
# ----------
# train Loss: 0.1291 Acc: 0.9476
# val Loss: 0.4961 Acc: 0.7922
#
# Epoch 62/99
# ----------
# train Loss: 0.1180 Acc: 0.9595
# val Loss: 0.5359 Acc: 0.7695
#
# Epoch 63/99
# ----------
# train Loss: 0.1112 Acc: 0.9651
# val Loss: 0.5680 Acc: 0.7695
#
# Epoch 64/99
# ----------
# train Loss: 0.1194 Acc: 0.9582
# val Loss: 0.4880 Acc: 0.8052
#
# Epoch 65/99
# ----------
# train Loss: 0.0970 Acc: 0.9719
# val Loss: 0.6794 Acc: 0.7370
#
# Epoch 66/99
# ----------
# train Loss: 0.1027 Acc: 0.9632
# val Loss: 0.4939 Acc: 0.8019
#
# Epoch 67/99
# ----------
# train Loss: 0.1140 Acc: 0.9632
# val Loss: 0.5417 Acc: 0.7630
#
# Epoch 68/99
# ----------
# train Loss: 0.1161 Acc: 0.9551
# val Loss: 0.5755 Acc: 0.7760
#
# Epoch 69/99
# ----------
# train Loss: 0.1103 Acc: 0.9626
# val Loss: 0.4715 Acc: 0.8052
#
# Epoch 70/99
# ----------
# train Loss: 0.1131 Acc: 0.9595
# val Loss: 0.4578 Acc: 0.8182
#
# Epoch 71/99
# ----------
# train Loss: 0.1028 Acc: 0.9688
# val Loss: 0.5705 Acc: 0.7727
#
# Epoch 72/99
# ----------
# train Loss: 0.1107 Acc: 0.9695
# val Loss: 0.5134 Acc: 0.7727
#
# Epoch 73/99
# ----------
# train Loss: 0.1085 Acc: 0.9620
# val Loss: 0.5220 Acc: 0.7695
#
# Epoch 74/99
# ----------
# train Loss: 0.1366 Acc: 0.9483
# val Loss: 0.4780 Acc: 0.7825
#
# Epoch 75/99
# ----------
# train Loss: 0.1174 Acc: 0.9601
# val Loss: 0.5528 Acc: 0.7792
#
# Epoch 76/99
# ----------
# train Loss: 0.1089 Acc: 0.9632
# val Loss: 0.5968 Acc: 0.7532
#
# Epoch 77/99
# ----------
# train Loss: 0.1080 Acc: 0.9626
# val Loss: 0.7142 Acc: 0.7208
#
# Epoch 78/99
# ----------
# train Loss: 0.1142 Acc: 0.9570
# val Loss: 0.5615 Acc: 0.7565
#
# Epoch 79/99
# ----------
# train Loss: 0.1111 Acc: 0.9564
# val Loss: 0.5082 Acc: 0.7662
#
# Epoch 80/99
# ----------
# train Loss: 0.1316 Acc: 0.9458
# val Loss: 0.5345 Acc: 0.7597
#
# Epoch 81/99
# ----------
# train Loss: 0.1107 Acc: 0.9582
# val Loss: 0.5871 Acc: 0.7630
#
# Epoch 82/99
# ----------
# train Loss: 0.1178 Acc: 0.9589
# val Loss: 0.6292 Acc: 0.7597
#
# Epoch 83/99
# ----------
# train Loss: 0.1144 Acc: 0.9613
# val Loss: 0.4938 Acc: 0.8117
#
# Epoch 84/99
# ----------
# train Loss: 0.1179 Acc: 0.9557
# val Loss: 0.5051 Acc: 0.8019
#
# Epoch 85/99
# ----------
# train Loss: 0.1178 Acc: 0.9651
# val Loss: 0.5703 Acc: 0.7597
#
# Epoch 86/99
# ----------
# train Loss: 0.1011 Acc: 0.9651
# val Loss: 0.4616 Acc: 0.7955
#
# Epoch 87/99
# ----------
# train Loss: 0.1171 Acc: 0.9582
# val Loss: 0.5426 Acc: 0.7792
#
# Epoch 88/99
# ----------
# train Loss: 0.1217 Acc: 0.9526
# val Loss: 0.4581 Acc: 0.8247
#
# Epoch 89/99
# ----------
# train Loss: 0.1127 Acc: 0.9657
# val Loss: 0.4527 Acc: 0.8084
#
# Epoch 90/99
# ----------
# train Loss: 0.1117 Acc: 0.9651
# val Loss: 0.5960 Acc: 0.7500
#
# Epoch 91/99
# ----------
# train Loss: 0.1115 Acc: 0.9595
# val Loss: 0.5561 Acc: 0.7597
#
# Epoch 92/99
# ----------
# train Loss: 0.1119 Acc: 0.9632
# val Loss: 0.5399 Acc: 0.7630
#
# Epoch 93/99
# ----------
# train Loss: 0.1092 Acc: 0.9638
# val Loss: 0.5064 Acc: 0.7857
#
# Epoch 94/99
# ----------
# train Loss: 0.1050 Acc: 0.9663
# val Loss: 0.5812 Acc: 0.7630
#
# Epoch 95/99
# ----------
# train Loss: 0.1195 Acc: 0.9576
# val Loss: 0.5641 Acc: 0.7662
#
# Epoch 96/99
# ----------
# train Loss: 0.1137 Acc: 0.9582
# val Loss: 0.4913 Acc: 0.7922
#
# Epoch 97/99
# ----------
# train Loss: 0.1075 Acc: 0.9582
# val Loss: 0.6045 Acc: 0.7630
#
# Epoch 98/99
# ----------
# train Loss: 0.1252 Acc: 0.9551
# val Loss: 0.4909 Acc: 0.7890
#
# Epoch 99/99
# ----------
# train Loss: 0.1116 Acc: 0.9638
# val Loss: 0.6555 Acc: 0.7500
#
# Training complete in 43m 32s
# Best val Acc: 0.834416

# %%
model_ft_freeze = train_model(model_ft_freeze, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.7115 Acc: 0.4969
# val Loss: 0.6855 Acc: 0.6461
#
# Epoch 1/99
# ----------
# train Loss: 0.6968 Acc: 0.5112
# val Loss: 1.1389 Acc: 0.3604
#
# Epoch 2/99
# ----------
# train Loss: 0.6964 Acc: 0.5050
# val Loss: 0.6641 Acc: 0.6753
#
# Epoch 3/99
# ----------
# train Loss: 0.6996 Acc: 0.4969
# val Loss: 0.7313 Acc: 0.3506
#
# Epoch 4/99
# ----------
# train Loss: 0.6990 Acc: 0.4988
# val Loss: 0.7465 Acc: 0.5519
#
# Epoch 5/99
# ----------
# train Loss: 0.6964 Acc: 0.5056
# val Loss: 0.6845 Acc: 0.4968
#
# Epoch 6/99
# ----------
# train Loss: 0.6959 Acc: 0.5050
# val Loss: 0.6899 Acc: 0.6169
#
# Epoch 7/99
# ----------
# train Loss: 0.6933 Acc: 0.5175
# val Loss: 0.6926 Acc: 0.5779
#
# Epoch 8/99
# ----------
# train Loss: 0.6926 Acc: 0.5106
# val Loss: 0.6939 Acc: 0.5682
#
# Epoch 9/99
# ----------
# train Loss: 0.6927 Acc: 0.5175
# val Loss: 0.6954 Acc: 0.5519
#
# Epoch 10/99
# ----------
# train Loss: 0.6924 Acc: 0.5156
# val Loss: 0.6955 Acc: 0.5714
#
# Epoch 11/99
# ----------
# train Loss: 0.6927 Acc: 0.5218
# val Loss: 0.6959 Acc: 0.5844
#
# Epoch 12/99
# ----------
# train Loss: 0.6916 Acc: 0.5206
# val Loss: 0.6970 Acc: 0.5844
#
# Epoch 13/99
# ----------
# train Loss: 0.6917 Acc: 0.5249
# val Loss: 0.6970 Acc: 0.5974
#
# Epoch 14/99
# ----------
# train Loss: 0.6893 Acc: 0.5368
# val Loss: 0.6994 Acc: 0.5714
#
# Epoch 15/99
# ----------
# train Loss: 0.6893 Acc: 0.5424
# val Loss: 0.6974 Acc: 0.5877
#
# Epoch 16/99
# ----------
# train Loss: 0.6886 Acc: 0.5349
# val Loss: 0.6987 Acc: 0.5974
#
# Epoch 17/99
# ----------
# train Loss: 0.6909 Acc: 0.5274
# val Loss: 0.6994 Acc: 0.5942
#
# Epoch 18/99
# ----------
# train Loss: 0.6887 Acc: 0.5330
# val Loss: 0.6986 Acc: 0.5909
#
# Epoch 19/99
# ----------
# train Loss: 0.6901 Acc: 0.5206
# val Loss: 0.6961 Acc: 0.5877
#
# Epoch 20/99
# ----------
# train Loss: 0.6902 Acc: 0.5380
# val Loss: 0.7062 Acc: 0.5584
#
# Epoch 21/99
# ----------
# train Loss: 0.6878 Acc: 0.5424
# val Loss: 0.7000 Acc: 0.5974
#
# Epoch 22/99
# ----------
# train Loss: 0.6888 Acc: 0.5393
# val Loss: 0.7026 Acc: 0.5552
#
# Epoch 23/99
# ----------
# train Loss: 0.6868 Acc: 0.5455
# val Loss: 0.7049 Acc: 0.5487
#
# Epoch 24/99
# ----------
# train Loss: 0.6901 Acc: 0.5281
# val Loss: 0.7000 Acc: 0.5909
#
# Epoch 25/99
# ----------
# train Loss: 0.6874 Acc: 0.5480
# val Loss: 0.7015 Acc: 0.5747
#
# Epoch 26/99
# ----------
# train Loss: 0.6893 Acc: 0.5517
# val Loss: 0.7001 Acc: 0.5974
#
# Epoch 27/99
# ----------
# train Loss: 0.6895 Acc: 0.5405
# val Loss: 0.6963 Acc: 0.6136
#
# Epoch 28/99
# ----------
# train Loss: 0.6889 Acc: 0.5362
# val Loss: 0.7020 Acc: 0.5747
#
# Epoch 29/99
# ----------
# train Loss: 0.6884 Acc: 0.5374
# val Loss: 0.7019 Acc: 0.5682
#
# Epoch 30/99
# ----------
# train Loss: 0.6893 Acc: 0.5436
# val Loss: 0.7040 Acc: 0.5682
#
# Epoch 31/99
# ----------
# train Loss: 0.6891 Acc: 0.5312
# val Loss: 0.6988 Acc: 0.6006
#
# Epoch 32/99
# ----------
# train Loss: 0.6900 Acc: 0.5374
# val Loss: 0.7013 Acc: 0.5812
#
# Epoch 33/99
# ----------
# train Loss: 0.6897 Acc: 0.5461
# val Loss: 0.6963 Acc: 0.6136
#
# Epoch 34/99
# ----------
# train Loss: 0.6887 Acc: 0.5374
# val Loss: 0.7040 Acc: 0.5714
#
# Epoch 35/99
# ----------
# train Loss: 0.6885 Acc: 0.5305
# val Loss: 0.7095 Acc: 0.5325
#
# Epoch 36/99
# ----------
# train Loss: 0.6895 Acc: 0.5480
# val Loss: 0.6977 Acc: 0.6071
#
# Epoch 37/99
# ----------
# train Loss: 0.6880 Acc: 0.5430
# val Loss: 0.7025 Acc: 0.5682
#
# Epoch 38/99
# ----------
# train Loss: 0.6896 Acc: 0.5312
# val Loss: 0.6977 Acc: 0.6039
#
# Epoch 39/99
# ----------
# train Loss: 0.6899 Acc: 0.5380
# val Loss: 0.6972 Acc: 0.6071
#
# Epoch 40/99
# ----------
# train Loss: 0.6901 Acc: 0.5293
# val Loss: 0.7012 Acc: 0.5747
#
# Epoch 41/99
# ----------
# train Loss: 0.6909 Acc: 0.5262
# val Loss: 0.7048 Acc: 0.5682
#
# Epoch 42/99
# ----------
# train Loss: 0.6893 Acc: 0.5349
# val Loss: 0.7037 Acc: 0.5487
#
# Epoch 43/99
# ----------
# train Loss: 0.6879 Acc: 0.5474
# val Loss: 0.7041 Acc: 0.5649
#
# Epoch 44/99
# ----------
# train Loss: 0.6884 Acc: 0.5393
# val Loss: 0.7019 Acc: 0.5812
#
# Epoch 45/99
# ----------
# train Loss: 0.6896 Acc: 0.5368
# val Loss: 0.7045 Acc: 0.5617
#
# Epoch 46/99
# ----------
# train Loss: 0.6909 Acc: 0.5274
# val Loss: 0.7033 Acc: 0.5584
#
# Epoch 47/99
# ----------
# train Loss: 0.6903 Acc: 0.5305
# val Loss: 0.6964 Acc: 0.6169
#
# Epoch 48/99
# ----------
# train Loss: 0.6882 Acc: 0.5349
# val Loss: 0.7093 Acc: 0.5292
#
# Epoch 49/99
# ----------
# train Loss: 0.6903 Acc: 0.5337
# val Loss: 0.6964 Acc: 0.6039
#
# Epoch 50/99
# ----------
# train Loss: 0.6883 Acc: 0.5443
# val Loss: 0.7011 Acc: 0.5844
#
# Epoch 51/99
# ----------
# train Loss: 0.6906 Acc: 0.5324
# val Loss: 0.7034 Acc: 0.5714
#
# Epoch 52/99
# ----------
# train Loss: 0.6888 Acc: 0.5262
# val Loss: 0.7005 Acc: 0.5877
#
# Epoch 53/99
# ----------
# train Loss: 0.6896 Acc: 0.5493
# val Loss: 0.7071 Acc: 0.5487
#
# Epoch 54/99
# ----------
# train Loss: 0.6921 Acc: 0.5168
# val Loss: 0.6994 Acc: 0.5974
#
# Epoch 55/99
# ----------
# train Loss: 0.6901 Acc: 0.5349
# val Loss: 0.7027 Acc: 0.5682
#
# Epoch 56/99
# ----------
# train Loss: 0.6916 Acc: 0.5125
# val Loss: 0.7026 Acc: 0.5682
#
# Epoch 57/99
# ----------
# train Loss: 0.6899 Acc: 0.5461
# val Loss: 0.7033 Acc: 0.5714
#
# Epoch 58/99
# ----------
# train Loss: 0.6883 Acc: 0.5443
# val Loss: 0.6990 Acc: 0.6071
#
# Epoch 59/99
# ----------
# train Loss: 0.6878 Acc: 0.5411
# val Loss: 0.6985 Acc: 0.6169
#
# Epoch 60/99
# ----------
# train Loss: 0.6881 Acc: 0.5256
# val Loss: 0.7030 Acc: 0.5714
#
# Epoch 61/99
# ----------
# train Loss: 0.6891 Acc: 0.5362
# val Loss: 0.7046 Acc: 0.5487
#
# Epoch 62/99
# ----------
# train Loss: 0.6889 Acc: 0.5380
# val Loss: 0.6981 Acc: 0.6006
#
# Epoch 63/99
# ----------
# train Loss: 0.6886 Acc: 0.5262
# val Loss: 0.6979 Acc: 0.6136
#
# Epoch 64/99
# ----------
# train Loss: 0.6892 Acc: 0.5468
# val Loss: 0.6982 Acc: 0.6071
#
# Epoch 65/99
# ----------
# train Loss: 0.6886 Acc: 0.5443
# val Loss: 0.7004 Acc: 0.6006
#
# Epoch 66/99
# ----------
# train Loss: 0.6863 Acc: 0.5599
# val Loss: 0.6966 Acc: 0.6104
#
# Epoch 67/99
# ----------
# train Loss: 0.6905 Acc: 0.5281
# val Loss: 0.7066 Acc: 0.5455
#
# Epoch 68/99
# ----------
# train Loss: 0.6883 Acc: 0.5561
# val Loss: 0.7001 Acc: 0.5974
#
# Epoch 69/99
# ----------
# train Loss: 0.6885 Acc: 0.5474
# val Loss: 0.7055 Acc: 0.5455
#
# Epoch 70/99
# ----------
# train Loss: 0.6886 Acc: 0.5555
# val Loss: 0.7053 Acc: 0.5552
#
# Epoch 71/99
# ----------
# train Loss: 0.6892 Acc: 0.5330
# val Loss: 0.7056 Acc: 0.5455
#
# Epoch 72/99
# ----------
# train Loss: 0.6885 Acc: 0.5455
# val Loss: 0.7017 Acc: 0.5584
#
# Epoch 73/99
# ----------
# train Loss: 0.6885 Acc: 0.5393
# val Loss: 0.7023 Acc: 0.5649
#
# Epoch 74/99
# ----------
# train Loss: 0.6876 Acc: 0.5418
# val Loss: 0.6975 Acc: 0.6006
#
# Epoch 75/99
# ----------
# train Loss: 0.6890 Acc: 0.5362
# val Loss: 0.6975 Acc: 0.6071
#
# Epoch 76/99
# ----------
# train Loss: 0.6890 Acc: 0.5443
# val Loss: 0.7029 Acc: 0.5584
#
# Epoch 77/99
# ----------
# train Loss: 0.6883 Acc: 0.5362
# val Loss: 0.7030 Acc: 0.5649
#
# Epoch 78/99
# ----------
# train Loss: 0.6895 Acc: 0.5418
# val Loss: 0.6971 Acc: 0.6104
#
# Epoch 79/99
# ----------
# train Loss: 0.6902 Acc: 0.5424
# val Loss: 0.7068 Acc: 0.5422
#
# Epoch 80/99
# ----------
# train Loss: 0.6886 Acc: 0.5393
# val Loss: 0.6989 Acc: 0.6006
#
# Epoch 81/99
# ----------
# train Loss: 0.6898 Acc: 0.5343
# val Loss: 0.7016 Acc: 0.5714
#
# Epoch 82/99
# ----------
# train Loss: 0.6907 Acc: 0.5287
# val Loss: 0.6983 Acc: 0.5974
#
# Epoch 83/99
# ----------
# train Loss: 0.6886 Acc: 0.5480
# val Loss: 0.7013 Acc: 0.5649
#
# Epoch 84/99
# ----------
# train Loss: 0.6894 Acc: 0.5430
# val Loss: 0.7021 Acc: 0.5714
#
# Epoch 85/99
# ----------
# train Loss: 0.6896 Acc: 0.5262
# val Loss: 0.6991 Acc: 0.5974
#
# Epoch 86/99
# ----------
# train Loss: 0.6885 Acc: 0.5274
# val Loss: 0.6999 Acc: 0.5779
#
# Epoch 87/99
# ----------
# train Loss: 0.6884 Acc: 0.5474
# val Loss: 0.7037 Acc: 0.5519
#
# Epoch 88/99
# ----------
# train Loss: 0.6908 Acc: 0.5330
# val Loss: 0.7033 Acc: 0.5649
#
# Epoch 89/99
# ----------
# train Loss: 0.6879 Acc: 0.5468
# val Loss: 0.7046 Acc: 0.5649
#
# Epoch 90/99
# ----------
# train Loss: 0.6883 Acc: 0.5337
# val Loss: 0.7022 Acc: 0.5649
#
# Epoch 91/99
# ----------
# train Loss: 0.6886 Acc: 0.5480
# val Loss: 0.7018 Acc: 0.5714
#
# Epoch 92/99
# ----------
# train Loss: 0.6883 Acc: 0.5424
# val Loss: 0.7069 Acc: 0.5617
#
# Epoch 93/99
# ----------
# train Loss: 0.6890 Acc: 0.5411
# val Loss: 0.7045 Acc: 0.5519
#
# Epoch 94/99
# ----------
# train Loss: 0.6893 Acc: 0.5455
# val Loss: 0.6991 Acc: 0.5942
#
# Epoch 95/99
# ----------
# train Loss: 0.6883 Acc: 0.5324
# val Loss: 0.6963 Acc: 0.6136
#
# Epoch 96/99
# ----------
# train Loss: 0.6888 Acc: 0.5330
# val Loss: 0.7028 Acc: 0.5584
#
# Epoch 97/99
# ----------
# train Loss: 0.6899 Acc: 0.5349
# val Loss: 0.7008 Acc: 0.5974
#
# Epoch 98/99
# ----------
# train Loss: 0.6889 Acc: 0.5387
# val Loss: 0.7023 Acc: 0.5779
#
# Epoch 99/99
# ----------
# train Loss: 0.6882 Acc: 0.5511
# val Loss: 0.7027 Acc: 0.5714
#
# Training complete in 46m 39s
# Best val Acc: 0.675325

# %% [markdown]
# # Visualize few image of the model without freezing layers

# %%
visualize_model(model_ft['model'])

plt.ioff()
plt.show()
# Out:
# Labels:tensor([0, 0, 1, 0], device='cuda:0')
# Prediction:tensor([0, 0, 1, 0], device='cuda:0')
# Input size: 4
# Class names: ['fake', 'real']
# Labels:tensor([0, 0, 1, 1], device='cuda:0')
# Prediction:tensor([1, 0, 1, 0], device='cuda:0')
# Input size: 4
# Class names: ['fake', 'real']

# %% [markdown]
# # Visualize few image of the model with freezing layers

# %%
visualize_model(model_ft_freeze['model'])

plt.ioff()
plt.show()
# Out:
# Labels:tensor([1, 1, 0, 1], device='cuda:0')
# Prediction:tensor([1, 1, 0, 1], device='cuda:0')
# Input size: 4
# Class names: ['fake', 'real']
# Labels:tensor([1, 0, 0, 1], device='cuda:0')
# Prediction:tensor([1, 0, 0, 1], device='cuda:0')
# Input size: 4
# Class names: ['fake', 'real']

# %% [markdown]
# # Plot Train Loss and Accuracy
#
#
#
# > In this section we plot the `training` and `validation loss` and the `accuracy` of our model without freezing layers.

# %%
def plot_logs(train_loss, valid_loss, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_loss))), train_loss, label='Train loss')
    plt.plot(list(range(len(valid_loss))), valid_loss, label='Valid loss')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc="upper right")

    plt.show()

plot_logs(model_ft['train_loss'], model_ft['val_loss'], 'Train vs Valid loss')

# %%
def plot_acc(train_acc, valid_acc, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_acc))), train_acc, label='Train accuracy')
    plt.plot(list(range(len(valid_acc))), valid_acc, label='Valid accuracy')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc="upper right")

    plt.show()
# oppure model_ft_freeze
plot_acc(model_ft['train_acc'], model_ft['val_acc'], 'Train vs Valid Accuracy')

# %% [markdown]
# # Plot Train Loss and Accuracy
#
#
#
# > In this section we plot the `training` and `validation loss` and the `accuracy` of our model with freezing layers.

# %%
def plot_logs(train_loss, valid_loss, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_loss))), train_loss, label='Train loss')
    plt.plot(list(range(len(valid_loss))), valid_loss, label='Valid loss')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc="upper right")

    plt.show()

plot_logs(model_ft_freeze['train_loss'], model_ft_freeze['val_loss'], 'Train vs Valid loss')

# %%
def plot_acc(train_acc, valid_acc, title: str):

    plt.figure(figsize=(8,6))

    plt.plot(list(range(len(train_acc))), train_acc, label='Train accuracy')
    plt.plot(list(range(len(valid_acc))), valid_acc, label='Valid accuracy')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc="upper right")

    plt.show()
# oppure model_ft_freeze
plot_acc(model_ft_freeze['train_acc'], model_ft_freeze['val_acc'], 'Train vs Valid Accuracy')

# %% [markdown]
# ## SAVE THE MODEL

# %%
# %cd /content/drive/MyDrive/VISIOPE_PROJECT/models
# Out:
# /content/drive/MyDrive/VISIOPE_PROJECT/models

# %% [markdown]
# ## WITHOUT FREEZING

# %%
torch.save(model_ft['model'].state_dict(), 'resnet50_deepfake_NORMAL_MIX.pt')

# %% [markdown]
# ## FREEZING

# %%
torch.save(model_ft_freeze['model'].state_dict(), 'resnet50_deepfake_FREEZE_MIX.pt')
